# %%
from sage.crypto.sbox import SBox
s_boxes = [((0xC,0xF,0x7,0xA,0xE,0xD,0xB,0x0,0x2,0x6,0x3,0x1,0x9,0x4,0x5,0x8),), ((0x7,0x2,0xE,0x9,0x3,0xB,0x0,0x4,0xC,0xD,0x1,0xA,0x6,0xF,0x8,0x5),), ((0xC,0x5,0x6,0xB,0x9,0x0,0xA,0xD,0x3,0xE,0xF,0x8,0x4,0x7,0x1,0x2),), ((0x5,0xE,0xF,0x8,0xC,0x1,0x2,0xD,0xB,0x4,0x6,0x3,0x0,0x7,0x9,0xA),), ((0x9,0x0,0x4,0xB,0xD,0xC,0x3,0xF,0x1,0xA,0x2,0x6,0x7,0x5,0x8,0xE),), ((0x3,0xC,0x6,0xD,0x5,0x7,0x1,0x9,0xF,0x2,0x0,0x4,0xB,0xA,0xE,0x8),), ((0xD,0x7,0x3,0x2,0x9,0xA,0xC,0x1,0xF,0x4,0x5,0xE,0x6,0x0,0xB,0x8),), ((0x4,0xA,0xF,0xC,0x0,0xD,0x9,0xB,0xE,0x6,0x1,0x7,0x3,0x5,0x8,0x2),), ((0xD,0xE,0x0,0x1,0x5,0xA,0x7,0x6,0xB,0x3,0x9,0xC,0xF,0x8,0x2,0x4),), ((0x7,0xA,0x2,0xC,0x4,0x8,0xF,0x0,0x5,0x9,0x1,0xE,0x3,0xD,0xB,0x6),), ((0xC,0xA,0xD,0x3,0xE,0xB,0xF,0x7,0x8,0x9,0x1,0x5,0x0,0x2,0x4,0x6),), ((0x8,0x6,0x7,0x9,0x3,0xC,0xA,0xF,0xD,0x1,0xE,0x4,0x0,0xB,0x5,0x2),), ((0x3,0x8,0xF,0x1,0xA,0x6,0x5,0xB,0xE,0xD,0x4,0x2,0x7,0x0,0x9,0xC),), ((0xF,0xC,0x2,0x7,0x9,0x0,0x5,0xA,0x1,0xB,0xE,0x8,0x6,0xD,0x3,0x4),), ((0x8,0x6,0x7,0x9,0x3,0xC,0xA,0xF,0xD,0x1,0xE,0x4,0x0,0xB,0x5,0x2),),((0x0, 0xF, 0xB, 0x8, 0xC, 0x9, 0x6, 0x3, 0xD, 0x1, 0x2, 0x4, 0xA, 0x7, 0x5, 0xE),), ((0x1, 0xF, 0x8, 0x3, 0xC, 0x0, 0xB, 0x6, 0x2, 0x5, 0x4, 0xA, 0x9, 0xE, 0x7, 0xD),),((0xF, 0x5, 0x2, 0xB, 0x4, 0xA, 0x9, 0xC, 0x0, 0x3, 0xE, 0x8, 0xD, 0x6, 0x7, 0x1),)];

# %%
s_box = SBox(s_boxes[0][0])
print("boomerang_uniformity: " + str(s_box.boomerang_uniformity()))
#print(s_box.difference_distribution_table()) 
print("fixed_points: " + str(s_box.fixed_points()))
print("has_linear_structure: " + str(s_box.has_linear_structure()))
print("is_almost_bent: " + str(s_box.is_almost_bent()))
print("is_apn: " + str(s_box.is_apn()))
print("differential_uniformity: " + str(s_box.differential_uniformity()))
print("maximal_difference_probability: " + str(s_box.maximal_difference_probability()))
print("maximal_difference_probability_absolute: " + str(s_box.maximal_difference_probability_absolute()))
print("maximal_linear_bias_absolute: " + str(s_box.maximal_linear_bias_absolute()))
print("maximal_linear_bias_relative: " + str(s_box.maximal_linear_bias_relative()))
print("is_balanced: " + str(s_box.is_balanced()))
print("is_involution: " + str(s_box.is_involution()))
print("is_permutation: " + str(s_box.is_permutation()))
print("linear_branch_number: " + str(s_box.linear_branch_number()))
print("differential_branch_number: " + str(s_box.differential_branch_number()))
print("min_degree: " + str(s_box.min_degree()))
print("max_degree: " + str(s_box.max_degree()))
print("linearity: " + str(s_box.linearity()))
print("nonlinearity: " + str(s_box.nonlinearity()))
# Out:
# boomerang_uniformity: 10
# fixed_points: []
# has_linear_structure: True
# is_almost_bent: False
# is_apn: False
# differential_uniformity: 6
# maximal_difference_probability: 0.375
# maximal_difference_probability_absolute: 6
# maximal_linear_bias_absolute: 6
# maximal_linear_bias_relative: 0.375
# is_balanced: True
# is_involution: False
# is_permutation: True
# linear_branch_number: 2
# differential_branch_number: 2
# min_degree: 3
# max_degree: 3
# linearity: 12
# nonlinearity: 2

# %%
s_box = SBox(s_boxes[1][0])
print("boomerang_uniformity: " + str(s_box.boomerang_uniformity()))
#print(s_box.difference_distribution_table()) 
print("fixed_points: " + str(s_box.fixed_points()))
print("has_linear_structure: " + str(s_box.has_linear_structure()))
print("is_almost_bent: " + str(s_box.is_almost_bent()))
print("is_apn: " + str(s_box.is_apn()))
print("differential_uniformity: " + str(s_box.differential_uniformity()))
print("maximal_difference_probability: " + str(s_box.maximal_difference_probability()))
print("maximal_difference_probability_absolute: " + str(s_box.maximal_difference_probability_absolute()))
print("maximal_linear_bias_absolute: " + str(s_box.maximal_linear_bias_absolute()))
print("maximal_linear_bias_relative: " + str(s_box.maximal_linear_bias_relative()))
print("is_balanced: " + str(s_box.is_balanced()))
print("is_involution: " + str(s_box.is_involution()))
print("is_permutation: " + str(s_box.is_permutation()))
print("linear_branch_number: " + str(s_box.linear_branch_number()))
print("differential_branch_number: " + str(s_box.differential_branch_number()))
print("min_degree: " + str(s_box.min_degree()))
print("max_degree: " + str(s_box.max_degree()))
print("linearity: " + str(s_box.linearity()))
print("nonlinearity: " + str(s_box.nonlinearity()))
# Out:
# boomerang_uniformity: 8
# fixed_points: []
# has_linear_structure: False
# is_almost_bent: False
# is_apn: False
# differential_uniformity: 6
# maximal_difference_probability: 0.375
# maximal_difference_probability_absolute: 6
# maximal_linear_bias_absolute: 4
# maximal_linear_bias_relative: 0.25
# is_balanced: True
# is_involution: False
# is_permutation: True
# linear_branch_number: 2
# differential_branch_number: 2
# min_degree: 3
# max_degree: 3
# linearity: 8
# nonlinearity: 4

# %%
s_box = SBox(s_boxes[2][0])
print("boomerang_uniformity: " + str(s_box.boomerang_uniformity()))
#print(s_box.difference_distribution_table()) 
print("fixed_points: " + str(s_box.fixed_points()))
print("has_linear_structure: " + str(s_box.has_linear_structure()))
print("is_almost_bent: " + str(s_box.is_almost_bent()))
print("is_apn: " + str(s_box.is_apn()))
print("differential_uniformity: " + str(s_box.differential_uniformity()))
print("maximal_difference_probability: " + str(s_box.maximal_difference_probability()))
print("maximal_difference_probability_absolute: " + str(s_box.maximal_difference_probability_absolute()))
print("maximal_linear_bias_absolute: " + str(s_box.maximal_linear_bias_absolute()))
print("maximal_linear_bias_relative: " + str(s_box.maximal_linear_bias_relative()))
print("is_balanced: " + str(s_box.is_balanced()))
print("is_involution: " + str(s_box.is_involution()))
print("is_permutation: " + str(s_box.is_permutation()))
print("linear_branch_number: " + str(s_box.linear_branch_number()))
print("differential_branch_number: " + str(s_box.differential_branch_number()))
print("min_degree: " + str(s_box.min_degree()))
print("max_degree: " + str(s_box.max_degree()))
print("linearity: " + str(s_box.linearity()))
print("nonlinearity: " + str(s_box.nonlinearity()))
# Out:
# boomerang_uniformity: 16
# fixed_points: []
# has_linear_structure: True
# is_almost_bent: False
# is_apn: False
# differential_uniformity: 4
# maximal_difference_probability: 0.25
# maximal_difference_probability_absolute: 4
# maximal_linear_bias_absolute: 4
# maximal_linear_bias_relative: 0.25
# is_balanced: True
# is_involution: False
# is_permutation: True
# linear_branch_number: 2
# differential_branch_number: 3
# min_degree: 2
# max_degree: 3
# linearity: 8
# nonlinearity: 4

# %%
s_box = SBox(s_boxes[3][0])
print("boomerang_uniformity: " + str(s_box.boomerang_uniformity()))
#print(s_box.difference_distribution_table()) 
print("fixed_points: " + str(s_box.fixed_points()))
print("has_linear_structure: " + str(s_box.has_linear_structure()))
print("is_almost_bent: " + str(s_box.is_almost_bent()))
print("is_apn: " + str(s_box.is_apn()))
print("differential_uniformity: " + str(s_box.differential_uniformity()))
print("maximal_difference_probability: " + str(s_box.maximal_difference_probability()))
print("maximal_difference_probability_absolute: " + str(s_box.maximal_difference_probability_absolute()))
print("maximal_linear_bias_absolute: " + str(s_box.maximal_linear_bias_absolute()))
print("maximal_linear_bias_relative: " + str(s_box.maximal_linear_bias_relative()))
print("is_balanced: " + str(s_box.is_balanced()))
print("is_involution: " + str(s_box.is_involution()))
print("is_permutation: " + str(s_box.is_permutation()))
print("linear_branch_number: " + str(s_box.linear_branch_number()))
print("differential_branch_number: " + str(s_box.differential_branch_number()))
print("min_degree: " + str(s_box.min_degree()))
print("max_degree: " + str(s_box.max_degree()))
print("linearity: " + str(s_box.linearity()))
print("nonlinearity: " + str(s_box.nonlinearity()))
# Out:
# boomerang_uniformity: 16
# fixed_points: []
# has_linear_structure: True
# is_almost_bent: False
# is_apn: False
# differential_uniformity: 4
# maximal_difference_probability: 0.25
# maximal_difference_probability_absolute: 4
# maximal_linear_bias_absolute: 4
# maximal_linear_bias_relative: 0.25
# is_balanced: True
# is_involution: False
# is_permutation: True
# linear_branch_number: 2
# differential_branch_number: 3
# min_degree: 2
# max_degree: 3
# linearity: 8
# nonlinearity: 4

# %%
s_box = SBox(s_boxes[4][0])
print(s_box)
print("boomerang_uniformity: " + str(s_box.boomerang_uniformity()))
#print(s_box.difference_distribution_table()) 
print("fixed_points: " + str(s_box.fixed_points()))
print("has_linear_structure: " + str(s_box.has_linear_structure()))
print("is_almost_bent: " + str(s_box.is_almost_bent()))
print("is_apn: " + str(s_box.is_apn()))
print("differential_uniformity: " + str(s_box.differential_uniformity()))
print("maximal_difference_probability: " + str(s_box.maximal_difference_probability()))
print("maximal_difference_probability_absolute: " + str(s_box.maximal_difference_probability_absolute()))
print("maximal_linear_bias_absolute: " + str(s_box.maximal_linear_bias_absolute()))
print("maximal_linear_bias_relative: " + str(s_box.maximal_linear_bias_relative()))
print("is_balanced: " + str(s_box.is_balanced()))
print("is_involution: " + str(s_box.is_involution()))
print("is_permutation: " + str(s_box.is_permutation()))
print("linear_branch_number: " + str(s_box.linear_branch_number()))
print("differential_branch_number: " + str(s_box.differential_branch_number()))
print("min_degree: " + str(s_box.min_degree()))
print("max_degree: " + str(s_box.max_degree()))
print("linearity: " + str(s_box.linearity()))
print("nonlinearity: " + str(s_box.nonlinearity()))
# Out:
# (9, 0, 4, 11, 13, 12, 3, 15, 1, 10, 2, 6, 7, 5, 8, 14)
# boomerang_uniformity: 10
# fixed_points: []
# has_linear_structure: False
# is_almost_bent: False
# is_apn: False
# differential_uniformity: 4
# maximal_difference_probability: 0.25
# maximal_difference_probability_absolute: 4
# maximal_linear_bias_absolute: 4
# maximal_linear_bias_relative: 0.25
# is_balanced: True
# is_involution: False
# is_permutation: True
# linear_branch_number: 2
# differential_branch_number: 2
# min_degree: 3
# max_degree: 3
# linearity: 8
# nonlinearity: 4

# %%
s_box = SBox(s_boxes[7][0])
print(s_box)
print("boomerang_uniformity: " + str(s_box.boomerang_uniformity()))
#print(s_box.difference_distribution_table()) 
print("fixed_points: " + str(s_box.fixed_points()))
print("has_linear_structure: " + str(s_box.has_linear_structure()))
print("is_almost_bent: " + str(s_box.is_almost_bent()))
print("is_apn: " + str(s_box.is_apn()))
print("differential_uniformity: " + str(s_box.differential_uniformity()))
print("maximal_difference_probability: " + str(s_box.maximal_difference_probability()))
print("maximal_difference_probability_absolute: " + str(s_box.maximal_difference_probability_absolute()))
print("maximal_linear_bias_absolute: " + str(s_box.maximal_linear_bias_absolute()))
print("maximal_linear_bias_relative: " + str(s_box.maximal_linear_bias_relative()))
print("is_balanced: " + str(s_box.is_balanced()))
print("is_involution: " + str(s_box.is_involution()))
print("is_permutation: " + str(s_box.is_permutation()))
print("linear_branch_number: " + str(s_box.linear_branch_number()))
print("differential_branch_number: " + str(s_box.differential_branch_number()))
print("min_degree: " + str(s_box.min_degree()))
print("max_degree: " + str(s_box.max_degree()))
print("linearity: " + str(s_box.linearity()))
print("nonlinearity: " + str(s_box.nonlinearity()))
# Out:
# (4, 10, 15, 12, 0, 13, 9, 11, 14, 6, 1, 7, 3, 5, 8, 2)
# boomerang_uniformity: 10
# fixed_points: []
# has_linear_structure: False
# is_almost_bent: False
# is_apn: False
# differential_uniformity: 4
# maximal_difference_probability: 0.25
# maximal_difference_probability_absolute: 4
# maximal_linear_bias_absolute: 4
# maximal_linear_bias_relative: 0.25
# is_balanced: True
# is_involution: True
# is_permutation: True
# linear_branch_number: 2
# differential_branch_number: 2
# min_degree: 3
# max_degree: 3
# linearity: 8
# nonlinearity: 4

# %%
s_box = SBox(s_boxes[8][0])
print(s_box)
print("boomerang_uniformity: " + str(s_box.boomerang_uniformity()))
#print(s_box.difference_distribution_table()) 
print("fixed_points: " + str(s_box.fixed_points()))
print("has_linear_structure: " + str(s_box.has_linear_structure()))
print("is_almost_bent: " + str(s_box.is_almost_bent()))
print("is_apn: " + str(s_box.is_apn()))
print("differential_uniformity: " + str(s_box.differential_uniformity()))
print("maximal_difference_probability: " + str(s_box.maximal_difference_probability()))
print("maximal_difference_probability_absolute: " + str(s_box.maximal_difference_probability_absolute()))
print("maximal_linear_bias_absolute: " + str(s_box.maximal_linear_bias_absolute()))
print("maximal_linear_bias_relative: " + str(s_box.maximal_linear_bias_relative()))
print("is_balanced: " + str(s_box.is_balanced()))
print("is_involution: " + str(s_box.is_involution()))
print("is_permutation: " + str(s_box.is_permutation()))
print("linear_branch_number: " + str(s_box.linear_branch_number()))
print("differential_branch_number: " + str(s_box.differential_branch_number()))
print("min_degree: " + str(s_box.min_degree()))
print("max_degree: " + str(s_box.max_degree()))
print("linearity: " + str(s_box.linearity()))
print("nonlinearity: " + str(s_box.nonlinearity()))
# Out:
# (13, 14, 0, 1, 5, 10, 7, 6, 11, 3, 9, 12, 15, 8, 2, 4)
# boomerang_uniformity: 16
# fixed_points: []
# has_linear_structure: True
# is_almost_bent: False
# is_apn: False
# differential_uniformity: 4
# maximal_difference_probability: 0.25
# maximal_difference_probability_absolute: 4
# maximal_linear_bias_absolute: 4
# maximal_linear_bias_relative: 0.25
# is_balanced: True
# is_involution: False
# is_permutation: True
# linear_branch_number: 2
# differential_branch_number: 2
# min_degree: 2
# max_degree: 3
# linearity: 8
# nonlinearity: 4

# %%
s_box = SBox(s_boxes[9][0])
print(s_box)
print("boomerang_uniformity: " + str(s_box.boomerang_uniformity()))
#print(s_box.difference_distribution_table()) 
print("fixed_points: " + str(s_box.fixed_points()))
print("has_linear_structure: " + str(s_box.has_linear_structure()))
print("is_almost_bent: " + str(s_box.is_almost_bent()))
print("is_apn: " + str(s_box.is_apn()))
print("differential_uniformity: " + str(s_box.differential_uniformity()))
print("maximal_difference_probability: " + str(s_box.maximal_difference_probability()))
print("maximal_difference_probability_absolute: " + str(s_box.maximal_difference_probability_absolute()))
print("maximal_linear_bias_absolute: " + str(s_box.maximal_linear_bias_absolute()))
print("maximal_linear_bias_relative: " + str(s_box.maximal_linear_bias_relative()))
print("is_balanced: " + str(s_box.is_balanced()))
print("is_involution: " + str(s_box.is_involution()))
print("is_permutation: " + str(s_box.is_permutation()))
print("linear_branch_number: " + str(s_box.linear_branch_number()))
print("differential_branch_number: " + str(s_box.differential_branch_number()))
print("min_degree: " + str(s_box.min_degree()))
print("max_degree: " + str(s_box.max_degree()))
print("linearity: " + str(s_box.linearity()))
print("nonlinearity: " + str(s_box.nonlinearity()))
# Out:
# (7, 10, 2, 12, 4, 8, 15, 0, 5, 9, 1, 14, 3, 13, 11, 6)
# boomerang_uniformity: 16
# fixed_points: [2, 4, 9, 13]
# has_linear_structure: True
# is_almost_bent: False
# is_apn: False
# differential_uniformity: 4
# maximal_difference_probability: 0.25
# maximal_difference_probability_absolute: 4
# maximal_linear_bias_absolute: 4
# maximal_linear_bias_relative: 0.25
# is_balanced: True
# is_involution: True
# is_permutation: True
# linear_branch_number: 2
# differential_branch_number: 2
# min_degree: 2
# max_degree: 3
# linearity: 8
# nonlinearity: 4

# %%
s_box = SBox(s_boxes[10][0])
print(s_box)
print("boomerang_uniformity: " + str(s_box.boomerang_uniformity()))
#print(s_box.difference_distribution_table()) 
print("fixed_points: " + str(s_box.fixed_points()))
print("has_linear_structure: " + str(s_box.has_linear_structure()))
print("is_almost_bent: " + str(s_box.is_almost_bent()))
print("is_apn: " + str(s_box.is_apn()))
print("differential_uniformity: " + str(s_box.differential_uniformity()))
print("maximal_difference_probability: " + str(s_box.maximal_difference_probability()))
print("maximal_difference_probability_absolute: " + str(s_box.maximal_difference_probability_absolute()))
print("maximal_linear_bias_absolute: " + str(s_box.maximal_linear_bias_absolute()))
print("maximal_linear_bias_relative: " + str(s_box.maximal_linear_bias_relative()))
print("is_balanced: " + str(s_box.is_balanced()))
print("is_involution: " + str(s_box.is_involution()))
print("is_permutation: " + str(s_box.is_permutation()))
print("linear_branch_number: " + str(s_box.linear_branch_number()))
print("differential_branch_number: " + str(s_box.differential_branch_number()))
print("min_degree: " + str(s_box.min_degree()))
print("max_degree: " + str(s_box.max_degree()))
print("linearity: " + str(s_box.linearity()))
print("nonlinearity: " + str(s_box.nonlinearity()))
# Out:
# (12, 10, 13, 3, 14, 11, 15, 7, 8, 9, 1, 5, 0, 2, 4, 6)
# boomerang_uniformity: 16
# fixed_points: [3, 7, 8, 9]
# has_linear_structure: True
# is_almost_bent: False
# is_apn: False
# differential_uniformity: 4
# maximal_difference_probability: 0.25
# maximal_difference_probability_absolute: 4
# maximal_linear_bias_absolute: 4
# maximal_linear_bias_relative: 0.25
# is_balanced: True
# is_involution: True
# is_permutation: True
# linear_branch_number: 2
# differential_branch_number: 2
# min_degree: 2
# max_degree: 3
# linearity: 8
# nonlinearity: 4

# %%
s_box = SBox(s_boxes[11][0])
print(s_box)
print("boomerang_uniformity: " + str(s_box.boomerang_uniformity()))
#print(s_box.difference_distribution_table()) 
print("fixed_points: " + str(s_box.fixed_points()))
print("has_linear_structure: " + str(s_box.has_linear_structure()))
print("is_almost_bent: " + str(s_box.is_almost_bent()))
print("is_apn: " + str(s_box.is_apn()))
print("differential_uniformity: " + str(s_box.differential_uniformity()))
print("maximal_difference_probability: " + str(s_box.maximal_difference_probability()))
print("maximal_difference_probability_absolute: " + str(s_box.maximal_difference_probability_absolute()))
print("maximal_linear_bias_absolute: " + str(s_box.maximal_linear_bias_absolute()))
print("maximal_linear_bias_relative: " + str(s_box.maximal_linear_bias_relative()))
print("is_balanced: " + str(s_box.is_balanced()))
print("is_involution: " + str(s_box.is_involution()))
print("is_permutation: " + str(s_box.is_permutation()))
print("linear_branch_number: " + str(s_box.linear_branch_number()))
print("differential_branch_number: " + str(s_box.differential_branch_number()))
print("min_degree: " + str(s_box.min_degree()))
print("max_degree: " + str(s_box.max_degree()))
print("linearity: " + str(s_box.linearity()))
print("nonlinearity: " + str(s_box.nonlinearity()))
# Out:
# (8, 6, 7, 9, 3, 12, 10, 15, 13, 1, 14, 4, 0, 11, 5, 2)
# boomerang_uniformity: 16
# fixed_points: []
# has_linear_structure: True
# is_almost_bent: False
# is_apn: False
# differential_uniformity: 4
# maximal_difference_probability: 0.25
# maximal_difference_probability_absolute: 4
# maximal_linear_bias_absolute: 4
# maximal_linear_bias_relative: 0.25
# is_balanced: True
# is_involution: False
# is_permutation: True
# linear_branch_number: 2
# differential_branch_number: 3
# min_degree: 2
# max_degree: 3
# linearity: 8
# nonlinearity: 4

# %%
s_box = SBox(s_boxes[12][0])
print(s_box)
print("boomerang_uniformity: " + str(s_box.boomerang_uniformity()))
#print(s_box.difference_distribution_table()) 
print("fixed_points: " + str(s_box.fixed_points()))
print("has_linear_structure: " + str(s_box.has_linear_structure()))
print("is_almost_bent: " + str(s_box.is_almost_bent()))
print("is_apn: " + str(s_box.is_apn()))
print("differential_uniformity: " + str(s_box.differential_uniformity()))
print("maximal_difference_probability: " + str(s_box.maximal_difference_probability()))
print("maximal_difference_probability_absolute: " + str(s_box.maximal_difference_probability_absolute()))
print("maximal_linear_bias_absolute: " + str(s_box.maximal_linear_bias_absolute()))
print("maximal_linear_bias_relative: " + str(s_box.maximal_linear_bias_relative()))
print("is_balanced: " + str(s_box.is_balanced()))
print("is_involution: " + str(s_box.is_involution()))
print("is_permutation: " + str(s_box.is_permutation()))
print("linear_branch_number: " + str(s_box.linear_branch_number()))
print("differential_branch_number: " + str(s_box.differential_branch_number()))
print("min_degree: " + str(s_box.min_degree()))
print("max_degree: " + str(s_box.max_degree()))
print("linearity: " + str(s_box.linearity()))
print("nonlinearity: " + str(s_box.nonlinearity()))
# Out:
# (3, 8, 15, 1, 10, 6, 5, 11, 14, 13, 4, 2, 7, 0, 9, 12)
# boomerang_uniformity: 16
# fixed_points: []
# has_linear_structure: True
# is_almost_bent: False
# is_apn: False
# differential_uniformity: 4
# maximal_difference_probability: 0.25
# maximal_difference_probability_absolute: 4
# maximal_linear_bias_absolute: 4
# maximal_linear_bias_relative: 0.25
# is_balanced: True
# is_involution: False
# is_permutation: True
# linear_branch_number: 2
# differential_branch_number: 3
# min_degree: 2
# max_degree: 3
# linearity: 8
# nonlinearity: 4

# %%
s_box = SBox(s_boxes[13][0])
print(s_box)
print("boomerang_uniformity: " + str(s_box.boomerang_uniformity()))
#print(s_box.difference_distribution_table()) 
print("fixed_points: " + str(s_box.fixed_points()))
print("has_linear_structure: " + str(s_box.has_linear_structure()))
print("is_almost_bent: " + str(s_box.is_almost_bent()))
print("is_apn: " + str(s_box.is_apn()))
print("differential_uniformity: " + str(s_box.differential_uniformity()))
print("maximal_difference_probability: " + str(s_box.maximal_difference_probability()))
print("maximal_difference_probability_absolute: " + str(s_box.maximal_difference_probability_absolute()))
print("maximal_linear_bias_absolute: " + str(s_box.maximal_linear_bias_absolute()))
print("maximal_linear_bias_relative: " + str(s_box.maximal_linear_bias_relative()))
print("is_balanced: " + str(s_box.is_balanced()))
print("is_involution: " + str(s_box.is_involution()))
print("is_permutation: " + str(s_box.is_permutation()))
print("linear_branch_number: " + str(s_box.linear_branch_number()))
print("differential_branch_number: " + str(s_box.differential_branch_number()))
print("min_degree: " + str(s_box.min_degree()))
print("max_degree: " + str(s_box.max_degree()))
print("linearity: " + str(s_box.linearity()))
print("nonlinearity: " + str(s_box.nonlinearity()))
# Out:
# (15, 12, 2, 7, 9, 0, 5, 10, 1, 11, 14, 8, 6, 13, 3, 4)
# boomerang_uniformity: 16
# fixed_points: [2, 13]
# has_linear_structure: True
# is_almost_bent: False
# is_apn: False
# differential_uniformity: 4
# maximal_difference_probability: 0.25
# maximal_difference_probability_absolute: 4
# maximal_linear_bias_absolute: 4
# maximal_linear_bias_relative: 0.25
# is_balanced: True
# is_involution: False
# is_permutation: True
# linear_branch_number: 2
# differential_branch_number: 3
# min_degree: 2
# max_degree: 3
# linearity: 8
# nonlinearity: 4

# %%
s_box = SBox(s_boxes[14][0])
print(s_box)
print("boomerang_uniformity: " + str(s_box.boomerang_uniformity()))
#print(s_box.difference_distribution_table()) 
print("fixed_points: " + str(s_box.fixed_points()))
print("has_linear_structure: " + str(s_box.has_linear_structure()))
print("is_almost_bent: " + str(s_box.is_almost_bent()))
print("is_apn: " + str(s_box.is_apn()))
print("differential_uniformity: " + str(s_box.differential_uniformity()))
print("maximal_difference_probability: " + str(s_box.maximal_difference_probability()))
print("maximal_difference_probability_absolute: " + str(s_box.maximal_difference_probability_absolute()))
print("maximal_linear_bias_absolute: " + str(s_box.maximal_linear_bias_absolute()))
print("maximal_linear_bias_relative: " + str(s_box.maximal_linear_bias_relative()))
print("is_balanced: " + str(s_box.is_balanced()))
print("is_involution: " + str(s_box.is_involution()))
print("is_permutation: " + str(s_box.is_permutation()))
print("linear_branch_number: " + str(s_box.linear_branch_number()))
print("differential_branch_number: " + str(s_box.differential_branch_number()))
print("min_degree: " + str(s_box.min_degree()))
print("max_degree: " + str(s_box.max_degree()))
print("linearity: " + str(s_box.linearity()))
print("nonlinearity: " + str(s_box.nonlinearity()))
# Out:
# (8, 6, 7, 9, 3, 12, 10, 15, 13, 1, 14, 4, 0, 11, 5, 2)
# boomerang_uniformity: 16
# fixed_points: []
# has_linear_structure: True
# is_almost_bent: False
# is_apn: False
# differential_uniformity: 4
# maximal_difference_probability: 0.25
# maximal_difference_probability_absolute: 4
# maximal_linear_bias_absolute: 4
# maximal_linear_bias_relative: 0.25
# is_balanced: True
# is_involution: False
# is_permutation: True
# linear_branch_number: 2
# differential_branch_number: 3
# min_degree: 2
# max_degree: 3
# linearity: 8
# nonlinearity: 4

# %%
s_box = SBox(s_boxes[15][0])
print(s_box)
print("boomerang_uniformity: " + str(s_box.boomerang_uniformity()))
#print(s_box.difference_distribution_table()) 
print("fixed_points: " + str(s_box.fixed_points()))
print("has_linear_structure: " + str(s_box.has_linear_structure()))
print("is_almost_bent: " + str(s_box.is_almost_bent()))
print("is_apn: " + str(s_box.is_apn()))
print("differential_uniformity: " + str(s_box.differential_uniformity()))
print("maximal_difference_probability: " + str(s_box.maximal_difference_probability()))
print("maximal_difference_probability_absolute: " + str(s_box.maximal_difference_probability_absolute()))
print("maximal_linear_bias_absolute: " + str(s_box.maximal_linear_bias_absolute()))
print("maximal_linear_bias_relative: " + str(s_box.maximal_linear_bias_relative()))
print("is_balanced: " + str(s_box.is_balanced()))
print("is_involution: " + str(s_box.is_involution()))
print("is_permutation: " + str(s_box.is_permutation()))
print("linear_branch_number: " + str(s_box.linear_branch_number()))
print("differential_branch_number: " + str(s_box.differential_branch_number()))
print("min_degree: " + str(s_box.min_degree()))
print("max_degree: " + str(s_box.max_degree()))
print("linearity: " + str(s_box.linearity()))
print("nonlinearity: " + str(s_box.nonlinearity()))
# Out:
# (0, 15, 11, 8, 12, 9, 6, 3, 13, 1, 2, 4, 10, 7, 5, 14)
# boomerang_uniformity: 10
# fixed_points: [0, 6]
# has_linear_structure: True
# is_almost_bent: False
# is_apn: False
# differential_uniformity: 4
# maximal_difference_probability: 0.25
# maximal_difference_probability_absolute: 4
# maximal_linear_bias_absolute: 4
# maximal_linear_bias_relative: 0.25
# is_balanced: True
# is_involution: False
# is_permutation: True
# linear_branch_number: 2
# differential_branch_number: 3
# min_degree: 2
# max_degree: 3
# linearity: 8
# nonlinearity: 4

# %%
s_box = SBox(s_boxes[16][0])
print(s_box)
print("boomerang_uniformity: " + str(s_box.boomerang_uniformity()))
#print(s_box.difference_distribution_table()) 
print("fixed_points: " + str(s_box.fixed_points()))
print("has_linear_structure: " + str(s_box.has_linear_structure()))
print("is_almost_bent: " + str(s_box.is_almost_bent()))
print("is_apn: " + str(s_box.is_apn()))
print("differential_uniformity: " + str(s_box.differential_uniformity()))
print("maximal_difference_probability: " + str(s_box.maximal_difference_probability()))
print("maximal_difference_probability_absolute: " + str(s_box.maximal_difference_probability_absolute()))
print("maximal_linear_bias_absolute: " + str(s_box.maximal_linear_bias_absolute()))
print("maximal_linear_bias_relative: " + str(s_box.maximal_linear_bias_relative()))
print("is_balanced: " + str(s_box.is_balanced()))
print("is_involution: " + str(s_box.is_involution()))
print("is_permutation: " + str(s_box.is_permutation()))
print("linear_branch_number: " + str(s_box.linear_branch_number()))
print("differential_branch_number: " + str(s_box.differential_branch_number()))
print("min_degree: " + str(s_box.min_degree()))
print("max_degree: " + str(s_box.max_degree()))
print("linearity: " + str(s_box.linearity()))
print("nonlinearity: " + str(s_box.nonlinearity()))
# Out:
# (1, 15, 8, 3, 12, 0, 11, 6, 2, 5, 4, 10, 9, 14, 7, 13)
# boomerang_uniformity: 10
# fixed_points: [3]
# has_linear_structure: True
# is_almost_bent: False
# is_apn: False
# differential_uniformity: 4
# maximal_difference_probability: 0.25
# maximal_difference_probability_absolute: 4
# maximal_linear_bias_absolute: 4
# maximal_linear_bias_relative: 0.25
# is_balanced: True
# is_involution: False
# is_permutation: True
# linear_branch_number: 2
# differential_branch_number: 3
# min_degree: 2
# max_degree: 3
# linearity: 8
# nonlinearity: 4

# %%
s_box = SBox(s_boxes[17][0])
print(s_box)
print("boomerang_uniformity: " + str(s_box.boomerang_uniformity()))
#print(s_box.difference_distribution_table()) 
print("fixed_points: " + str(s_box.fixed_points()))
print("has_linear_structure: " + str(s_box.has_linear_structure()))
print("is_almost_bent: " + str(s_box.is_almost_bent()))
print("is_apn: " + str(s_box.is_apn()))
print("differential_uniformity: " + str(s_box.differential_uniformity()))
print("maximal_difference_probability: " + str(s_box.maximal_difference_probability()))
print("maximal_difference_probability_absolute: " + str(s_box.maximal_difference_probability_absolute()))
print("maximal_linear_bias_absolute: " + str(s_box.maximal_linear_bias_absolute()))
print("maximal_linear_bias_relative: " + str(s_box.maximal_linear_bias_relative()))
print("is_balanced: " + str(s_box.is_balanced()))
print("is_involution: " + str(s_box.is_involution()))
print("is_permutation: " + str(s_box.is_permutation()))
print("linear_branch_number: " + str(s_box.linear_branch_number()))
print("differential_branch_number: " + str(s_box.differential_branch_number()))
print("min_degree: " + str(s_box.min_degree()))
print("max_degree: " + str(s_box.max_degree()))
print("linearity: " + str(s_box.linearity()))
print("nonlinearity: " + str(s_box.nonlinearity()))
# Out:
# (15, 5, 2, 11, 4, 10, 9, 12, 0, 3, 14, 8, 13, 6, 7, 1)
# boomerang_uniformity: 10
# fixed_points: [2, 4]
# has_linear_structure: True
# is_almost_bent: False
# is_apn: False
# differential_uniformity: 4
# maximal_difference_probability: 0.25
# maximal_difference_probability_absolute: 4
# maximal_linear_bias_absolute: 4
# maximal_linear_bias_relative: 0.25
# is_balanced: True
# is_involution: False
# is_permutation: True
# linear_branch_number: 2
# differential_branch_number: 3
# min_degree: 2
# max_degree: 3
# linearity: 8
# nonlinearity: 4

# %%
s_box = SBox(0x1, 0xD, 0xF, 0x0, 0xE, 0x8, 0x2, 0xB, 0x7, 0x4, 0xC, 0xA, 0x9, 0x3, 0x5, 0x6)
print(s_box)
print("boomerang_uniformity: " + str(s_box.boomerang_uniformity()))
#print(s_box.difference_distribution_table()) 
print("fixed_points: " + str(s_box.fixed_points()))
print("has_linear_structure: " + str(s_box.has_linear_structure()))
print("is_almost_bent: " + str(s_box.is_almost_bent()))
print("is_apn: " + str(s_box.is_apn()))
print("differential_uniformity: " + str(s_box.differential_uniformity()))
print("maximal_difference_probability: " + str(s_box.maximal_difference_probability()))
print("maximal_difference_probability_absolute: " + str(s_box.maximal_difference_probability_absolute()))
print("maximal_linear_bias_absolute: " + str(s_box.maximal_linear_bias_absolute()))
print("maximal_linear_bias_relative: " + str(s_box.maximal_linear_bias_relative()))
print("is_balanced: " + str(s_box.is_balanced()))
print("is_involution: " + str(s_box.is_involution()))
print("is_permutation: " + str(s_box.is_permutation()))
print("linear_branch_number: " + str(s_box.linear_branch_number()))
print("differential_branch_number: " + str(s_box.differential_branch_number()))
print("min_degree: " + str(s_box.min_degree()))
print("max_degree: " + str(s_box.max_degree()))
print("linearity: " + str(s_box.linearity()))
print("nonlinearity: " + str(s_box.nonlinearity()))
# Out:
# (1, 13, 15, 0, 14, 8, 2, 11, 7, 4, 12, 10, 9, 3, 5, 6)
# boomerang_uniformity: 10
# fixed_points: []
# has_linear_structure: True
# is_almost_bent: False
# is_apn: False
# differential_uniformity: 4
# maximal_difference_probability: 0.25
# maximal_difference_probability_absolute: 4
# maximal_linear_bias_absolute: 4
# maximal_linear_bias_relative: 0.25
# is_balanced: True
# is_involution: False
# is_permutation: True
# linear_branch_number: 2
# differential_branch_number: 3
# min_degree: 2
# max_degree: 3
# linearity: 8
# nonlinearity: 4

# %%
s_box = SBox(s_boxes[15][0])
print(s_box)
print("boomerang_uniformity: " + str(s_box.boomerang_uniformity()))
#print(s_box.difference_distribution_table()) 
print("fixed_points: " + str(s_box.fixed_points()))
print("has_linear_structure: " + str(s_box.has_linear_structure()))
print("is_almost_bent: " + str(s_box.is_almost_bent()))
print("is_apn: " + str(s_box.is_apn()))
print("differential_uniformity: " + str(s_box.differential_uniformity()))
print("maximal_difference_probability: " + str(s_box.maximal_difference_probability()))
print("maximal_difference_probability_absolute: " + str(s_box.maximal_difference_probability_absolute()))
print("maximal_linear_bias_absolute: " + str(s_box.maximal_linear_bias_absolute()))
print("maximal_linear_bias_relative: " + str(s_box.maximal_linear_bias_relative()))
print("is_balanced: " + str(s_box.is_balanced()))
print("is_involution: " + str(s_box.is_involution()))
print("is_permutation: " + str(s_box.is_permutation()))
print("linear_branch_number: " + str(s_box.linear_branch_number()))
print("differential_branch_number: " + str(s_box.differential_branch_number()))
print("min_degree: " + str(s_box.min_degree()))
print("max_degree: " + str(s_box.max_degree()))
print("linearity: " + str(s_box.linearity()))
print("nonlinearity: " + str(s_box.nonlinearity()))
# Out:
# (0, 15, 11, 8, 12, 9, 6, 3, 13, 1, 2, 4, 10, 7, 5, 14)
# boomerang_uniformity: 10
# fixed_points: [0, 6]
# has_linear_structure: True
# is_almost_bent: False
# is_apn: False
# differential_uniformity: 4
# maximal_difference_probability: 0.25
# maximal_difference_probability_absolute: 4
# maximal_linear_bias_absolute: 4
# maximal_linear_bias_relative: 0.25
# is_balanced: True
# is_involution: False
# is_permutation: True
# linear_branch_number: 2
# differential_branch_number: 3
# min_degree: 2
# max_degree: 3
# linearity: 8
# nonlinearity: 4

# %%
s_box = SBox(0x7, 0xC, 0xE, 0x9, 0x2, 0x1, 0x5, 0xF, 0xB, 0x6, 0xD, 0x0, 0x4, 0x8, 0xA, 0x3)
print(s_box)
print("boomerang_uniformity: " + str(s_box.boomerang_uniformity()))
#print(s_box.difference_distribution_table()) 
print("fixed_points: " + str(s_box.fixed_points()))
print("has_linear_structure: " + str(s_box.has_linear_structure()))
print("is_almost_bent: " + str(s_box.is_almost_bent()))
print("is_apn: " + str(s_box.is_apn()))
print("differential_uniformity: " + str(s_box.differential_uniformity()))
print("maximal_difference_probability: " + str(s_box.maximal_difference_probability()))
print("maximal_difference_probability_absolute: " + str(s_box.maximal_difference_probability_absolute()))
print("maximal_linear_bias_absolute: " + str(s_box.maximal_linear_bias_absolute()))
print("maximal_linear_bias_relative: " + str(s_box.maximal_linear_bias_relative()))
print("is_balanced: " + str(s_box.is_balanced()))
print("is_involution: " + str(s_box.is_involution()))
print("is_permutation: " + str(s_box.is_permutation()))
print("linear_branch_number: " + str(s_box.linear_branch_number()))
print("differential_branch_number: " + str(s_box.differential_branch_number()))
print("min_degree: " + str(s_box.min_degree()))
print("max_degree: " + str(s_box.max_degree()))
print("linearity: " + str(s_box.linearity()))
print("nonlinearity: " + str(s_box.nonlinearity()))
# Out:
# (7, 12, 14, 9, 2, 1, 5, 15, 11, 6, 13, 0, 4, 8, 10, 3)
# boomerang_uniformity: 10
# fixed_points: []
# has_linear_structure: True
# is_almost_bent: False
# is_apn: False
# differential_uniformity: 4
# maximal_difference_probability: 0.25
# maximal_difference_probability_absolute: 4
# maximal_linear_bias_absolute: 4
# maximal_linear_bias_relative: 0.25
# is_balanced: True
# is_involution: False
# is_permutation: True
# linear_branch_number: 2
# differential_branch_number: 3
# min_degree: 2
# max_degree: 3
# linearity: 8
# nonlinearity: 4

# %%
s_box = SBox(0xC, 0x5, 0x6, 0xB, 0x9, 0x0, 0xA, 0xD, 0x3, 0xE, 0xF, 0x8, 0x4, 0x7, 0x1, 0x2)
print(s_box)
print("boomerang_uniformity: " + str(s_box.boomerang_uniformity()))
#print(s_box.difference_distribution_table()) 
print("fixed_points: " + str(s_box.fixed_points()))
print("has_linear_structure: " + str(s_box.has_linear_structure()))
print("is_almost_bent: " + str(s_box.is_almost_bent()))
print("is_apn: " + str(s_box.is_apn()))
print("differential_uniformity: " + str(s_box.differential_uniformity()))
print("maximal_difference_probability: " + str(s_box.maximal_difference_probability()))
print("maximal_difference_probability_absolute: " + str(s_box.maximal_difference_probability_absolute()))
print("maximal_linear_bias_absolute: " + str(s_box.maximal_linear_bias_absolute()))
print("maximal_linear_bias_relative: " + str(s_box.maximal_linear_bias_relative()))
print("is_balanced: " + str(s_box.is_balanced()))
print("is_involution: " + str(s_box.is_involution()))
print("is_permutation: " + str(s_box.is_permutation()))
print("linear_branch_number: " + str(s_box.linear_branch_number()))
print("differential_branch_number: " + str(s_box.differential_branch_number()))
print("min_degree: " + str(s_box.min_degree()))
print("max_degree: " + str(s_box.max_degree()))
print("linearity: " + str(s_box.linearity()))
print("nonlinearity: " + str(s_box.nonlinearity()))
# Out:
# (12, 5, 6, 11, 9, 0, 10, 13, 3, 14, 15, 8, 4, 7, 1, 2)
# boomerang_uniformity: 16
# fixed_points: []
# has_linear_structure: True
# is_almost_bent: False
# is_apn: False
# differential_uniformity: 4
# maximal_difference_probability: 0.25
# maximal_difference_probability_absolute: 4
# maximal_linear_bias_absolute: 4
# maximal_linear_bias_relative: 0.25
# is_balanced: True
# is_involution: False
# is_permutation: True
# linear_branch_number: 2
# differential_branch_number: 3
# min_degree: 2
# max_degree: 3
# linearity: 8
# nonlinearity: 4

# %%
s_box = SBox(0xE, 0x9, 0xF, 0x0, 0xD, 0x4, 0xA, 0xB, 0x1, 0x2, 0x8, 0x3, 0x7, 0x6, 0xC, 0x5)
print(s_box)
print("boomerang_uniformity: " + str(s_box.boomerang_uniformity()))
#print(s_box.difference_distribution_table()) 
print("fixed_points: " + str(s_box.fixed_points()))
print("has_linear_structure: " + str(s_box.has_linear_structure()))
print("is_almost_bent: " + str(s_box.is_almost_bent()))
print("is_apn: " + str(s_box.is_apn()))
print("differential_uniformity: " + str(s_box.differential_uniformity()))
print("maximal_difference_probability: " + str(s_box.maximal_difference_probability()))
print("maximal_difference_probability_absolute: " + str(s_box.maximal_difference_probability_absolute()))
print("maximal_linear_bias_absolute: " + str(s_box.maximal_linear_bias_absolute()))
print("maximal_linear_bias_relative: " + str(s_box.maximal_linear_bias_relative()))
print("is_balanced: " + str(s_box.is_balanced()))
print("is_involution: " + str(s_box.is_involution()))
print("is_permutation: " + str(s_box.is_permutation()))
print("linear_branch_number: " + str(s_box.linear_branch_number()))
print("differential_branch_number: " + str(s_box.differential_branch_number()))
print("min_degree: " + str(s_box.min_degree()))
print("max_degree: " + str(s_box.max_degree()))
print("linearity: " + str(s_box.linearity()))
print("nonlinearity: " + str(s_box.nonlinearity()))
# Out:
# (14, 9, 15, 0, 13, 4, 10, 11, 1, 2, 8, 3, 7, 6, 12, 5)
# boomerang_uniformity: 16
# fixed_points: []
# has_linear_structure: True
# is_almost_bent: False
# is_apn: False
# differential_uniformity: 4
# maximal_difference_probability: 0.25
# maximal_difference_probability_absolute: 4
# maximal_linear_bias_absolute: 4
# maximal_linear_bias_relative: 0.25
# is_balanced: True
# is_involution: False
# is_permutation: True
# linear_branch_number: 2
# differential_branch_number: 2
# min_degree: 2
# max_degree: 3
# linearity: 8
# nonlinearity: 4

# %%
s_box = SBox(0x3, 0xF, 0xE, 0x1, 0x0, 0xA, 0x5, 0x8, 0xC, 0x4, 0xB, 0x2, 0x9, 0x7, 0x6, 0xD )
print(s_box)
print("boomerang_uniformity: " + str(s_box.boomerang_uniformity()))
#print(s_box.difference_distribution_table()) 
print("fixed_points: " + str(s_box.fixed_points()))
print("has_linear_structure: " + str(s_box.has_linear_structure()))
print("is_almost_bent: " + str(s_box.is_almost_bent()))
print("is_apn: " + str(s_box.is_apn()))
print("differential_uniformity: " + str(s_box.differential_uniformity()))
print("maximal_difference_probability: " + str(s_box.maximal_difference_probability()))
print("maximal_difference_probability_absolute: " + str(s_box.maximal_difference_probability_absolute()))
print("maximal_linear_bias_absolute: " + str(s_box.maximal_linear_bias_absolute()))
print("maximal_linear_bias_relative: " + str(s_box.maximal_linear_bias_relative()))
print("is_balanced: " + str(s_box.is_balanced()))
print("is_involution: " + str(s_box.is_involution()))
print("is_permutation: " + str(s_box.is_permutation()))
print("linear_branch_number: " + str(s_box.linear_branch_number()))
print("differential_branch_number: " + str(s_box.differential_branch_number()))
print("min_degree: " + str(s_box.min_degree()))
print("max_degree: " + str(s_box.max_degree()))
print("linearity: " + str(s_box.linearity()))
print("nonlinearity: " + str(s_box.nonlinearity()))
# Out:
# (3, 15, 14, 1, 0, 10, 5, 8, 12, 4, 11, 2, 9, 7, 6, 13)
# boomerang_uniformity: 16
# fixed_points: []
# has_linear_structure: True
# is_almost_bent: False
# is_apn: False
# differential_uniformity: 4
# maximal_difference_probability: 0.25
# maximal_difference_probability_absolute: 4
# maximal_linear_bias_absolute: 4
# maximal_linear_bias_relative: 0.25
# is_balanced: True
# is_involution: False
# is_permutation: True
# linear_branch_number: 2
# differential_branch_number: 2
# min_degree: 2
# max_degree: 3
# linearity: 8
# nonlinearity: 4
